# %%
import pandas as pd
df=pd.read_csv("https://github.com/prasertcbs/tutorial/raw/master/thai_provinces.csv")
df
# Out:
#    provinceID       provinceTh                provinceEn regionID    areaKm2
# 0          นม       นครราชสีมา         Nakhon Ratchasima       NE  20493.964
# 1          ชม        เชียงใหม่                Chiang Mai        N  20107.057
# 2          กจ        กาญจนบุรี              Kanchanaburi        C  19483.148
# 3          ตก              ตาก                       Tak        N  16406.650
# 4          อบ      อุบลราชธานี          Ubon Ratchathani       NE  16112.650
# 5          สฎ     สุราษฎร์ธานี               Surat Thani        S  12891.469
# 6          ชย          ชัยภูมิ                Chaiyaphum       NE  12778.287
# 7          มส       แม่ฮ่องสอน              Mae Hong Son        N  12681.259
# 8          พช        เพชรบูรณ์                Phetchabun        N  12668.416
# 9          ลป            ลำปาง                   Lampang        N  12533.961
# 10         อด         อุดรธานี                Udon Thani       NE  11730.302
# ...

# %%
df1 = df.set_index('provinceID')
df1
# Out:
#                  provinceTh                provinceEn regionID    areaKm2
# provinceID
# นม               นครราชสีมา         Nakhon Ratchasima       NE  20493.964
# ชม                เชียงใหม่                Chiang Mai        N  20107.057
# กจ                กาญจนบุรี              Kanchanaburi        C  19483.148
# ตก                      ตาก                       Tak        N  16406.650
# อบ              อุบลราชธานี          Ubon Ratchathani       NE  16112.650
# สฎ             สุราษฎร์ธานี               Surat Thani        S  12891.469
# ชย                  ชัยภูมิ                Chaiyaphum       NE  12778.287
# มส               แม่ฮ่องสอน              Mae Hong Son        N  12681.259
# พช                เพชรบูรณ์                Phetchabun        N  12668.416
# ลป                    ลำปาง                   Lampang        N  12533.961
# อด                 อุดรธานี                Udon Thani       NE  11730.302
# ...

# %%
df1.set_index(['provinceEn' , 'regionID'], append= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'provinceEn'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-cf4b67092f4e> in <module>
# ...

# %%
df1.set_index(['provinceTh' , 'areaKm2'], inplace=True)
df1
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df.reset_index()
# Out:
#     index provinceID       provinceTh                provinceEn regionID  \
# 0       0         นม       นครราชสีมา         Nakhon Ratchasima       NE
# 1       1         ชม        เชียงใหม่                Chiang Mai        N
# 2       2         กจ        กาญจนบุรี              Kanchanaburi        C
# 3       3         ตก              ตาก                       Tak        N
# 4       4         อบ      อุบลราชธานี          Ubon Ratchathani       NE
# 5       5         สฎ     สุราษฎร์ธานี               Surat Thani        S
# 6       6         ชย          ชัยภูมิ                Chaiyaphum       NE
# 7       7         มส       แม่ฮ่องสอน              Mae Hong Son        N
# 8       8         พช        เพชรบูรณ์                Phetchabun        N
# 9       9         ลป            ลำปาง                   Lampang        N
# 10     10         อด         อุดรธานี                Udon Thani       NE
# 11     11         ชร         เชียงราย                Chiang Rai        N
# ...

# %%
df1.reset_index()
# Out:
#          provinceTh    areaKm2
# 0        นครราชสีมา  20493.964
# 1         เชียงใหม่  20107.057
# 2         กาญจนบุรี  19483.148
# 3               ตาก  16406.650
# 4       อุบลราชธานี  16112.650
# 5      สุราษฎร์ธานี  12891.469
# 6           ชัยภูมิ  12778.287
# 7        แม่ฮ่องสอน  12681.259
# 8         เพชรบูรณ์  12668.416
# 9             ลำปาง  12533.961
# 10         อุดรธานี  11730.302
# 11         เชียงราย  11678.369
# 12             น่าน  11472.072
# 13              เลย  11424.612
# 14          ขอนแก่น  10885.991
# 15         พิษณุโลก  10815.854
# 16        บุรีรัมย์  10322.885
# 17    นครศรีธรรมราช   9942.502
# 18           สกลนคร   9605.764
# 19        นครสวรรค์   9597.677
# 20         ศรีสะเกษ   8839.976
# 21        กำแพงเพชร   8607.490
# 22         ร้อยเอ็ด   8299.449
# 23         สุรินทร์   8124.056
# 24        อุตรดิตถ์   7838.592
# 25            สงขลา   7393.889
# 26          หนองคาย   7332.280
# 27          สระแก้ว   7195.436
# 28        กาฬสินธุ์   6946.746
# ...

# %%
df
# Out:
#    provinceID       provinceTh                provinceEn regionID    areaKm2
# 0          นม       นครราชสีมา         Nakhon Ratchasima       NE  20493.964
# 1          ชม        เชียงใหม่                Chiang Mai        N  20107.057
# 2          กจ        กาญจนบุรี              Kanchanaburi        C  19483.148
# 3          ตก              ตาก                       Tak        N  16406.650
# 4          อบ      อุบลราชธานี          Ubon Ratchathani       NE  16112.650
# 5          สฎ     สุราษฎร์ธานี               Surat Thani        S  12891.469
# 6          ชย          ชัยภูมิ                Chaiyaphum       NE  12778.287
# 7          มส       แม่ฮ่องสอน              Mae Hong Son        N  12681.259
# 8          พช        เพชรบูรณ์                Phetchabun        N  12668.416
# 9          ลป            ลำปาง                   Lampang        N  12533.961
# 10         อด         อุดรธานี                Udon Thani       NE  11730.302
# ...
