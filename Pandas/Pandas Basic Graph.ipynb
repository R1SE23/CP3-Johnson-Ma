# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/prasertcbs/tutorial/master/mpg.csv')
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CC177A6E10>,
# ...
#       dtype=object)

# %%
df.cty.hist()

# %%
df.cty.hist();

# %%
df.cty.hist(bins=20)

# %%
df[['cty', 'hwy']].hist(grid=False, color= 'orange', sharex=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CC17F0B6D8>,
# ...
#       dtype=object)

# %%
# share x --> look the graph above
df[['cty', 'hwy']].hist(grid=False, color= 'orange')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CC192C2F98>,
# ...
#       dtype=object)

# %%
df[['cty', 'hwy']].plot.hist()

# %%
df[['cty', 'hwy']].plot.hist(alpha=.4)

# %%
df.cty.plot.density()

# %%
df.cty.plot.kde() ## same as density

# %%
df['class'].value_counts().plot.barh(color='purple')                        #### reserve word like class use [ ]

# %%
df['class'].value_counts().plot.barh(color='.8')

# %%
df['class'].value_counts().sort_values().plot.barh(color='.8')
