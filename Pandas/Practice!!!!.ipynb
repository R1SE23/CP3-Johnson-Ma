# %%
import pandas as pd
import numpy as np
df=pd.read_csv('https://raw.githubusercontent.com/prasertcbs/tutorial/master/mpg.csv')
df
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 0           audi                      a4    1.8  1999    4    auto(l5)   f
# 1           audi                      a4    1.8  1999    4  manual(m5)   f
# 2           audi                      a4    2.0  2008    4  manual(m6)   f
# 3           audi                      a4    2.0  2008    4    auto(av)   f
# 4           audi                      a4    2.8  1999    6    auto(l5)   f
# 5           audi                      a4    2.8  1999    6  manual(m5)   f
# 6           audi                      a4    3.1  2008    6    auto(av)   f
# 7           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 8           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 9           audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 10          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df['model'].value_counts().sum()
# Out:
# 234

# %%
df[['displ','cyl']].dropna().value_counts()
# Out:
# displ  cyl
# 2.0    4      21
# 4.7    8      17
# 1.8    4      14
# 2.5    4      14
# 4.0    6      14
# 2.4    4      13
# 4.6    8      11
# 2.8    6      10
# 3.3    6       9
# 3.8    6       8
# 3.0    6       8
# 5.7    8       8
# 5.4    8       8
# 3.1    6       6
# 5.3    8       6
# 2.2    4       6
# 2.7    4       5
# 3.5    6       5
# 1.6    4       5
# 5.2    8       5
# 3.4    6       4
# 2.5    5       4
# 3.9    6       3
# 1.9    4       3
# 2.7    6       3
# 3.7    6       3
# 4.2    6       2
#        8       2
# 5.0    8       2
# 2.5    6       2
# 3.6    6       2
# 5.9    8       2
# 6.2    8       2
# 4.4    8       1
# 6.5    8       1
# 4.0    8       1
# 5.6    8       1
# 6.0    8       1
# 6.1    8       1
# 7.0    8       1
# dtype: int64

# %%
df.iloc[df[['displ','cyl']].dropna().value_counts()]
# Out:
#    manufacturer               model  displ  year  cyl       trans drv  cty  \
# 21    chevrolet  c1500 suburban 2wd    5.7  1999    8    auto(l4)   r   13
# 17         audi          a6 quattro    4.2  2008    8    auto(s6)   4   16
# 14         audi          a4 quattro    3.1  2008    6  manual(m6)   4   15
# 14         audi          a4 quattro    3.1  2008    6  manual(m6)   4   15
# 14         audi          a4 quattro    3.1  2008    6  manual(m6)   4   15
# 13         audi          a4 quattro    3.1  2008    6    auto(s6)   4   17
# 11         audi          a4 quattro    2.8  1999    6    auto(l5)   4   15
# 10         audi          a4 quattro    2.0  2008    4    auto(s6)   4   19
# 9          audi          a4 quattro    2.0  2008    4  manual(m6)   4   20
# 8          audi          a4 quattro    1.8  1999    4    auto(l5)   4   16
# 8          audi          a4 quattro    1.8  1999    4    auto(l5)   4   16
# ...

# %%
df[(df['displ'] == 5.7)] 
df.pivot_table(values=['displ','cty'], index='manufacturer',aggfunc='mean')
# Out:
#                     cty     displ
# manufacturer
# audi          17.611111  2.544444
# chevrolet     15.000000  5.063158
# dodge         13.135135  4.378378
# ford          14.000000  4.536000
# honda         24.444444  1.711111
# hyundai       18.642857  2.428571
# jeep          13.500000  4.575000
# land rover    11.500000  4.300000
# lincoln       11.333333  5.400000
# mercury       13.250000  4.400000
# nissan        18.076923  3.269231
# pontiac       17.000000  3.960000
# subaru        19.285714  2.457143
# toyota        18.529412  2.952941
# volkswagen    20.925926  2.255556

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.887431  0.026658 -1.210692  0.861185
# 2013-01-02 -1.284534  0.220736 -0.055033 -0.719731
# 2013-01-03  1.174292 -0.641266 -1.333899  0.128719
# 2013-01-04  0.402971  0.538642 -0.720151 -0.498329
# 2013-01-05  0.633318 -2.145674 -2.505305  1.910145
# 2013-01-06  1.094029 -0.564233 -0.175756 -0.590585

# %%
 df2 = pd.DataFrame({'A': 1.,
   ...:                     'B': pd.Timestamp('20130102'),
   ...:                     'C': pd.Series(1, index=list(range(4)), dtype='float32'),
   ...:                     'D': np.array([3] * 4, dtype='int32'),
   ...:                     'E': pd.Categorical(["test", "train", "test", "train"]),
   ...:                     'F': 'foo'})

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.to_numpy()
# Out:
# array([[ 1.88743102,  0.02665781, -1.21069229,  0.86118457],
#        [-1.28453401,  0.22073599, -0.05503332, -0.71973099],
#        [ 1.17429154, -0.64126619, -1.33389851,  0.12871916],
#        [ 0.40297083,  0.53864208, -0.72015078, -0.49832859],
#        [ 0.6333182 , -2.14567443, -2.50530544,  1.91014456],
#        [ 1.09402929, -0.56423286, -0.1757563 , -0.59058536]])

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    1.887431   -1.284534    1.174292    0.402971    0.633318    1.094029
# B    0.026658    0.220736   -0.641266    0.538642   -2.145674   -0.564233
# C   -1.210692   -0.055033   -1.333899   -0.720151   -2.505305   -0.175756
# D    0.861185   -0.719731    0.128719   -0.498329    1.910145   -0.590585

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                    1                    1                    1
# B  2013-01-02 00:00:00  2013-01-02 00:00:00  2013-01-02 00:00:00
# C                    1                    1                    1
# D                    3                    3                    3
# E                 test                train                 test
# F                  foo                  foo                  foo
#
#                      3
# A                    1
# B  2013-01-02 00:00:00
# C                    1
# D                    3
# E                train
# F                  foo

# %%
df["A"]
# Out:
# 2013-01-01    1.887431
# 2013-01-02   -1.284534
# 2013-01-03    1.174292
# 2013-01-04    0.402971
# 2013-01-05    0.633318
# 2013-01-06    1.094029
# Freq: D, Name: A, dtype: float64

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.887431  0.026658 -1.210692  0.861185
# 2013-01-02 -1.284534  0.220736 -0.055033 -0.719731
# 2013-01-03  1.174292 -0.641266 -1.333899  0.128719
# 2013-01-04  0.402971  0.538642 -0.720151 -0.498329
# 2013-01-05  0.633318 -2.145674 -2.505305  1.910145
# 2013-01-06  1.094029 -0.564233 -0.175756 -0.590585

# %%
df.iloc[:,2] # selection by position
# Out:
# 2013-01-01   -1.210692
# 2013-01-02   -0.055033
# 2013-01-03   -1.333899
# 2013-01-04   -0.720151
# 2013-01-05   -2.505305
# 2013-01-06   -0.175756
# Freq: D, Name: C, dtype: float64

# %%
df.loc['20130102', ['A', 'B']] # selection by label
# Out:
# A   -1.284534
# B    0.220736
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df[df['A'] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.887431  0.026658 -1.210692  0.861185
# 2013-01-03  1.174292 -0.641266 -1.333899  0.128719
# 2013-01-04  0.402971  0.538642 -0.720151 -0.498329
# 2013-01-05  0.633318 -2.145674 -2.505305  1.910145
# 2013-01-06  1.094029 -0.564233 -0.175756 -0.590585

# %%
df[df > 0]
# Out:
#                    A         B   C         D
# 2013-01-01  1.887431  0.026658 NaN  0.861185
# 2013-01-02       NaN  0.220736 NaN       NaN
# 2013-01-03  1.174292       NaN NaN  0.128719
# 2013-01-04  0.402971  0.538642 NaN       NaN
# 2013-01-05  0.633318       NaN NaN  1.910145
# 2013-01-06  1.094029       NaN NaN       NaN

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2 =df.copy()

# %%
df2['E']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'E'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-5c108085a3cb> in <module>
# ----> 1 df2['E']
#
# ...
